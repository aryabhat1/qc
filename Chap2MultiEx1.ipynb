# %%
from qiskit import *
import numpy as np
from math import pi
from qiskit.visualization import plot_bloch_multivector, plot_histogram

# %% [raw]
# qc = QuantumCircuit(3)
# for qubit in range(3):
#     qc.h(qubit)
# qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc, backend).result().get_statevector()

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.draw('mpl')

# %%
backend = Aer.get_backend('unitary_simulator')
unitary = execute(qc, backend).result().get_unitary()

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.z(1)
qc.h(1)
qc.draw('mpl')

# %%
results = execute(qc, backend).result().get_counts()
plot_histogram(results)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-9-c316f4256376> in <module>
# ----> 1 results = execute(qc, backend).result().get_counts()
#       2 plot_histogram(results)
#
# ~/anaconda3/envs/vquant/lib/python3.6/site-packages/qiskit/result/result.py in get_counts(self, experiment)
#     194                 dict_list.append(Statevector(vec).probabilities_dict(decimals=15))
#     195             else:
# --> 196                 raise QiskitError('No counts for experiment "{0}"'.format(key))
#     197
#     198         # Return first item of dict_list if size is 1
#
# QiskitError: 'No counts for experiment "0"'

# %%
qc.h(0)
qc.h(1)
qc.cx(0, 1)
qc.draw('mpl')

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.cx(0, 1)
display(qc.draw('mpl'))

# %%
statevector_backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc, statevector_backend).result().get_statevector()
plot_bloch_multivector(final_state)

# %%
from qiskit import QuantumCircuit
from qiskit.circuit import Gate
from math import pi
qc = QuantumCircuit(2)
c = 0
t = 1

# %%
qc.cz(c, t)
qc.draw('mpl')

# %%
qc.sdg(t)
qc.cx(c, t)
qc.s(t)
qc.draw('mpl')

# %%
qc.ry(pi/4, t)
qc.cx(c, t)
qc.ry(-pi/4, t)
qc.draw('mpl')
