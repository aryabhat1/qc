# %%
from qiskit import QuantumCircuit, execute, Aer

# %%
from qiskit.visualization import plot_histogram

# %%
from qiskit_textbook.widgets import binary_widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-364e1ad4541b> in <module>
# ----> 1 from qiskit_textbook.widgets import binary_widget
#
# ModuleNotFoundError: No module named 'qiskit_textbook'

# %%
n = 8
n_q = n
n_b = n
qc_output = QuantumCircuit(n_q, n_b)

# %%
for j in range(n):
    qc_output.measure(j, j)

# %%
qc_output.draw(output='mpl', justify='none')

# %%
counts = execute(qc_output, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
qc_encode = QuantumCircuit(n)
qc_encode.h(7)

# %%
qc_encode.draw(output='mpl', justify='none')

# %%
qc = qc_encode + qc_output
qc.draw(output='mpl', justify='none')

# %%
qc_encode = QuantumCircuit(n)
qc_encode.x(1)
qc_encode.h(5)

qc_encode.draw(output = 'mpl', justify='none')
